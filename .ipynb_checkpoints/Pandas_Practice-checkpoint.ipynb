# %% [markdown]
# import numpy as np
# import pandas as pd

# %%
data = [1,3,3,3,3]

ser = pd.Series(data)

ser

#Series is th one dimentional data structure. If we arenot providing the index, a defulat index wil be created by pandas library
# Out:
# 0    1
# 1    3
# 2    3
# 3    3
# 4    3
# dtype: int64

# %%
data = [1,2,3,3,3]
index = ['a','b','c','d','e']

ser = pd.Series(data,index)

ser
# Out:
# a    1
# b    2
# c    3
# d    3
# e    3
# dtype: int64

# %%
# not only list we can also insert numpy arry

data = np.random.random(100)

print(data)

index = np.arange(100)

print(index)


ser = pd.Series(data, index)

ser
# Out:
# [0.68591082 0.70376508 0.16210878 0.21769804 0.84795764 0.41532279
#  0.50841594 0.32478016 0.52598893 0.44401112 0.4657124  0.25967044
#  0.6144067  0.75357599 0.74252549 0.95763539 0.18146548 0.06254269
#  0.14320129 0.3047907  0.30132072 0.94860871 0.50618862 0.64414411
#  0.0627577  0.61983935 0.52813814 0.77088881 0.81841021 0.53513946
#  0.77638905 0.98765386 0.14640576 0.51374731 0.45684385 0.62211742
#  0.39768669 0.30154688 0.89267689 0.86037122 0.23859193 0.34720607
#  0.22574463 0.83799835 0.35830895 0.35558704 0.63335518 0.22390378
#  0.00592204 0.21344086 0.37967184 0.84751667 0.63235592 0.09482881
#  0.72755789 0.38806917 0.05296781 0.05691572 0.05605541 0.19228004
#  0.10742347 0.23851812 0.19072281 0.27257672 0.03130866 0.27969101
#  0.83468428 0.12157606 0.52646923 0.34616664 0.15228903 0.65677514
#  0.31236457 0.99484085 0.00876193 0.8349496  0.42961004 0.46532381
#  0.38330099 0.09626973 0.31066387 0.17625834 0.43749349 0.32473618
# ...

# %%
dataDict = {'a':1,"b":2,"c":3,"d":4,"e":5}

ser = pd.Series(dataDict)

ser
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
 movie = pd.read_csv('movie.csv')
    
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movie.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
director = movie.director_name

director
# Out:
# 0            James Cameron
# 1           Gore Verbinski
# 2               Sam Mendes
# 3        Christopher Nolan
# 4              Doug Walker
# 5           Andrew Stanton
# 6                Sam Raimi
# 7             Nathan Greno
# 8              Joss Whedon
# 9              David Yates
# 10             Zack Snyder
# 11            Bryan Singer
# 12            Marc Forster
# 13          Gore Verbinski
# 14          Gore Verbinski
# 15             Zack Snyder
# 16          Andrew Adamson
# 17             Joss Whedon
# 18            Rob Marshall
# 19        Barry Sonnenfeld
# 20           Peter Jackson
# 21               Marc Webb
# 22            Ridley Scott
# 23           Peter Jackson
# 24             Chris Weitz
# 25           Peter Jackson
# 26           James Cameron
# 27           Anthony Russo
# 28              Peter Berg
# 29         Colin Trevorrow
#                ...
# 4886            Eric Eason
# 4887              Uwe Boll
# 4888     Richard Linklater
# ...

# %%
director.to_frame()
# Out:
#            director_name
# 0          James Cameron
# 1         Gore Verbinski
# 2             Sam Mendes
# 3      Christopher Nolan
# 4            Doug Walker
# 5         Andrew Stanton
# 6              Sam Raimi
# 7           Nathan Greno
# 8            Joss Whedon
# 9            David Yates
# 10           Zack Snyder
# 11          Bryan Singer
# 12          Marc Forster
# 13        Gore Verbinski
# 14        Gore Verbinski
# 15           Zack Snyder
# 16        Andrew Adamson
# 17           Joss Whedon
# 18          Rob Marshall
# 19      Barry Sonnenfeld
# 20         Peter Jackson
# 21             Marc Webb
# 22          Ridley Scott
# 23         Peter Jackson
# 24           Chris Weitz
# 25         Peter Jackson
# 26         James Cameron
# 27         Anthony Russo
# 28            Peter Berg
# 29       Colin Trevorrow
# ...                  ...
# 4886          Eric Eason
# 4887            Uwe Boll
# 4888   Richard Linklater
# 4889     Joseph Mazzella
# 4890        Travis Legge
# ...

# %%
s_attr_methods = set(dir(pd.Series))
len(s_attr_methods)

#it displays the avaiable method in series library
# Out:
# 471

# %% [markdown]
# *** Read two series with different data types

# %%
df = pd.read_csv('movie.csv')
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
fblikes = df['director_facebook_likes']

type(fblikes)
# Out:
# pandas.core.series.Series

# %%
critic_reviews = df.num_critic_for_reviews

type(critic_reviews
    )

critic_reviews.head()
# Out:
# 0    723.0
# 1    302.0
# 2    602.0
# 3    813.0
# 4      NaN
# Name: num_critic_for_reviews, dtype: float64

# %% [markdown]
# **value_counts method avaiable for a series, used to deterime the count of the unique value

# %%
director = df.director_name

# %%
print((director.value_counts()>20).head())

print(len(director))
print('count {}'.format(director.count()))
# Out:
# Steven Spielberg     True
# Woody Allen          True
# Martin Scorsese     False
# Clint Eastwood      False
# Spike Lee           False
# Name: director_name, dtype: bool
# 4916
# count 4814

# %%
director.describe()

##Descirbe method on Series gives out and out different result as compared to df.describe()
# Out:
# count                 4814
# unique                2397
# top       Steven Spielberg
# freq                    26
# Name: director_name, dtype: object

# %%
director.isnull().count()

#null values are 4916
# Out:
# 4916

# %%
d = director.fillna("Not Available")
d.dropna()
# Out:
# 0            James Cameron
# 1           Gore Verbinski
# 2               Sam Mendes
# 3        Christopher Nolan
# 4              Doug Walker
# 5           Andrew Stanton
# 6                Sam Raimi
# 7             Nathan Greno
# 8              Joss Whedon
# 9              David Yates
# 10             Zack Snyder
# 11            Bryan Singer
# 12            Marc Forster
# 13          Gore Verbinski
# 14          Gore Verbinski
# 15             Zack Snyder
# 16          Andrew Adamson
# 17             Joss Whedon
# 18            Rob Marshall
# 19        Barry Sonnenfeld
# 20           Peter Jackson
# 21               Marc Webb
# 22            Ridley Scott
# 23           Peter Jackson
# 24             Chris Weitz
# 25           Peter Jackson
# 26           James Cameron
# 27           Anthony Russo
# 28              Peter Berg
# 29         Colin Trevorrow
#                ...
# 4886            Eric Eason
# 4887              Uwe Boll
# 4888     Richard Linklater
# ...

# %%
director.value_counts(normalize=True)
# Out:
# Steven Spielberg        0.005401
# Woody Allen             0.004570
# Martin Scorsese         0.004155
# Clint Eastwood          0.004155
# Spike Lee               0.003324
# Ridley Scott            0.003324
# Renny Harlin            0.003116
# Steven Soderbergh       0.003116
# Oliver Stone            0.002908
# Tim Burton              0.002908
# Robert Zemeckis         0.002700
# Ron Howard              0.002700
# Barry Levinson          0.002700
# Robert Rodriguez        0.002700
# Joel Schumacher         0.002700
# Michael Bay             0.002493
# Tony Scott              0.002493
# Brian De Palma          0.002493
# Kevin Smith             0.002493
# Shawn Levy              0.002285
# Chris Columbus          0.002285
# Rob Reiner              0.002285
# Richard Donner          0.002285
# Sam Raimi               0.002285
# Richard Linklater       0.002285
# Francis Ford Coppola    0.002285
# David Fincher           0.002077
# John Carpenter          0.002077
# ...

# %%
director.hasnans
# Out:
# True

# %%
d.hasnans
# Out:
# False

# %%
director.eq('James Cameron')
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26       True
# 27      False
# 28      False
# 29      False
#         ...
# 4886    False
# 4887    False
# 4888    False
# 4889    False
# 4890    False
# 4891    False
# 4892    False
# 4893    False
# 4894    False
# 4895    False
# 4896    False
# 4897    False
# 4898    False
# 4899    False
# 4900    False
# 4901    False
# 4902    False
# 4903    False
# 4904    False
# 4905    False
# 4906    False
# 4907    False
# 4908    False
# 4909    False
# 4910    False
# 4911    False
# 4912    False
# 4913    False
# 4914    False
# 4915    False
# ...

# %%
d.isnull().sum()
# Out:
# 0

# %%
print('percentage of null values {}'.format(100-director.isnull().mean()))
# Out:
# percentage of null values 99.9792514239219

# %%
100-director.isnull().mean()
# Out:
# 99.9792514239219

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# **Name for index

# %%
df = df.set_index('movie_title')

# %%
df
# Out:
#                                                        color  \
# movie_title
# Avatar                                                 Color
# Pirates of the Caribbean: At World's End               Color
# Spectre                                                Color
# The Dark Knight Rises                                  Color
# Star Wars: Episode VII - The Force Awakens               NaN
# John Carter                                            Color
# Spider-Man 3                                           Color
# Tangled                                                Color
# Avengers: Age of Ultron                                Color
# Harry Potter and the Half-Blood Prince                 Color
# Batman v Superman: Dawn of Justice                     Color
# Superman Returns                                       Color
# Quantum of Solace                                      Color
# Pirates of the Caribbean: Dead Man's Chest             Color
# ...

# %%
df.reset_index()
# Out:
#                                       movie_title            color  \
# 0                                          Avatar            Color
# 1        Pirates of the Caribbean: At World's End            Color
# 2                                         Spectre            Color
# 3                           The Dark Knight Rises            Color
# 4      Star Wars: Episode VII - The Force Awakens              NaN
# 5                                     John Carter            Color
# 6                                    Spider-Man 3            Color
# 7                                         Tangled            Color
# 8                         Avengers: Age of Ultron            Color
# 9          Harry Potter and the Half-Blood Prince            Color
# 10             Batman v Superman: Dawn of Justice            Color
# 11                               Superman Returns            Color
# 12                              Quantum of Solace            Color
# ...

# %%
movie = pd.read_csv('movie.csv', index_col='movie_title')

# %%
index = movie.index

ind = index.tolist()

for i,val in enumerate(ind):
    if val == "Avatar":
        ind[i] = "Changed XXX"
        
        
movie.index = ind

movie.head()
# Out:
#                                             color      director_name  \
# Changed XXX                                 Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# Changed XXX                                                  723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# ...

# %%
columns = movie.columns

col = columns.tolist()

col[0] = 'color_XXX'

movie.columns = col

movie.head()
# Out:
#                                            color_XXX      director_name  \
# Changed XXX                                    Color      James Cameron
# Pirates of the Caribbean: At World's End       Color     Gore Verbinski
# Spectre                                        Color         Sam Mendes
# The Dark Knight Rises                          Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens       NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# Changed XXX                                                  723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
movie['newCol'] = "NA"

movie.head()
# Out:
#                                            color_XXX      director_name  \
# Changed XXX                                    Color      James Cameron
# Pirates of the Caribbean: At World's End       Color     Gore Verbinski
# Spectre                                        Color         Sam Mendes
# The Dark Knight Rises                          Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens       NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# Changed XXX                                                  723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
movie = movie.drop(columns='newCol')

# %%
movie.head()
# Out:
#                                            color_XXX      director_name  \
# Changed XXX                                    Color      James Cameron
# Pirates of the Caribbean: At World's End       Color     Gore Verbinski
# Spectre                                        Color         Sam Mendes
# The Dark Knight Rises                          Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens       NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# Changed XXX                                                  723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
movie = movie.drop(columns='director_name')

# %%
movie.head()
# Out:
#                                            color_XXX  num_critic_for_reviews  \
# Changed XXX                                    Color                   723.0
# Pirates of the Caribbean: At World's End       Color                   302.0
# Spectre                                        Color                   602.0
# The Dark Knight Rises                          Color                   813.0
# Star Wars: Episode VII - The Force Awakens       NaN                     NaN
#
#                                             duration  director_facebook_likes  \
# Changed XXX                                    178.0                      0.0
# Pirates of the Caribbean: At World's End       169.0                    563.0
# Spectre                                        148.0                      0.0
# The Dark Knight Rises                          164.0                  22000.0
# Star Wars: Episode VII - The Force Awakens       NaN                    131.0
#
# ...

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'num_voted_users', 'cast_total_facebook_likes', 'actor_3_name',
#        'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
colList = ['color','movie_facebook_likes','imdb_score','plot_keywords']

df[colList]
# Out:
#                                                        color  \
# movie_title
# Avatar                                                 Color
# Pirates of the Caribbean: At World's End               Color
# Spectre                                                Color
# The Dark Knight Rises                                  Color
# Star Wars: Episode VII - The Force Awakens               NaN
# John Carter                                            Color
# Spider-Man 3                                           Color
# Tangled                                                Color
# Avengers: Age of Ultron                                Color
# Harry Potter and the Half-Blood Prince                 Color
# Batman v Superman: Dawn of Justice                     Color
# Superman Returns                                       Color
# Quantum of Solace                                      Color
# Pirates of the Caribbean: Dead Man's Chest             Color
# ...

# %%
df.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
df.T
# Out:
# movie_title                                                           Avatar  \
# color                                                                  Color
# director_name                                                  James Cameron
# num_critic_for_reviews                                                   723
# duration                                                                 178
# director_facebook_likes                                                    0
# actor_3_facebook_likes                                                   855
# actor_2_name                                                Joel David Moore
# actor_1_facebook_likes                                                  1000
# gross                                                            7.60506e+08
# genres                                       Action|Adventure|Fantasy|Sci-Fi
# actor_1_name                                                     CCH Pounder
# ...

# %%
df.get_dtype_counts()
# Out:
# float64    13
# int64       3
# object     11
# dtype: int64

# %%
df.select_dtypes(include=['float']).head()
# Out:
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
# ...

# %%
df.select_dtypes(include=['number']).head()
# Out:
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
# ...

# %%
df.filter(like='facebook').head()
# Out:
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                             actor_1_facebook_likes  \
# movie_title
# ...

# %%
a = ['director_facebook_likes','movie_facebook_likes']
b = ['num_user_for_reviews']
c = ['color']

# %%
newcol_order = a + b + c

# %%
set(df.columns) == set(newcol_order)
# Out:
# False

# %%
df.ndim
# Out:
# 2

# %%
colge = pd.read_csv('college.csv')

colge.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# ...

# %%
colge.columns
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %%
colge.isnull().sum(axis=0).sort_values(ascending=False).head()
# Out:
# SATVRMID           6350
# SATMTMID           6339
# MD_EARN_WNE_P10    1122
# UG25ABV             817
# PCTFLOAN            686
# dtype: int64

# %%
k =colge.dropna(how='all')

# %%
k.isnull().sum()
# Out:
# INSTNM                   0
# CITY                     0
# STABBR                   0
# HBCU                   371
# MENONLY                371
# WOMENONLY              371
# RELAFFIL                 0
# SATVRMID              6350
# SATMTMID              6339
# DISTANCEONLY           371
# UGDS                   661
# UGDS_WHITE             661
# UGDS_BLACK             661
# UGDS_HISP              661
# UGDS_ASIAN             661
# UGDS_AIAN              661
# UGDS_NHPI              661
# UGDS_2MOR              661
# UGDS_NRA               661
# UGDS_UNKN              661
# PPTUG_EF               682
# CURROPER                 0
# PCTPELL                686
# PCTFLOAN               686
# UG25ABV                817
# MD_EARN_WNE_P10       1122
# GRAD_DEBT_MDN_SUPP      32
# dtype: int64

# %%
colge.memory_usage(deep=True)
# Out:
# Index                     80
# INSTNM                660240
# CITY                  496019
# STABBR                444565
# HBCU                   60280
# MENONLY                60280
# WOMENONLY              60280
# RELAFFIL               60280
# SATVRMID               60280
# SATMTMID               60280
# DISTANCEONLY           60280
# UGDS                   60280
# UGDS_WHITE             60280
# UGDS_BLACK             60280
# UGDS_HISP              60280
# UGDS_ASIAN             60280
# UGDS_AIAN              60280
# UGDS_NHPI              60280
# UGDS_2MOR              60280
# UGDS_NRA               60280
# UGDS_UNKN              60280
# PPTUG_EF               60280
# CURROPER               60280
# PCTPELL                60280
# PCTFLOAN               60280
# UG25ABV                60280
# MD_EARN_WNE_P10       443397
# GRAD_DEBT_MDN_SUPP    484160
# dtype: int64

# %%
colge.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# ...

# %%
movie.head()
# Out:
#                                            color_XXX  num_critic_for_reviews  \
# Changed XXX                                    Color                   723.0
# Pirates of the Caribbean: At World's End       Color                   302.0
# Spectre                                        Color                   602.0
# The Dark Knight Rises                          Color                   813.0
# Star Wars: Episode VII - The Force Awakens       NaN                     NaN
#
#                                             duration  director_facebook_likes  \
# Changed XXX                                    178.0                      0.0
# Pirates of the Caribbean: At World's End       169.0                    563.0
# Spectre                                        148.0                      0.0
# The Dark Knight Rises                          164.0                  22000.0
# Star Wars: Episode VII - The Force Awakens       NaN                    131.0
#
# ...

# %%
movie.columns
# Out:
# Index(['color_XXX', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'num_voted_users', 'cast_total_facebook_likes', 'actor_3_name',
#        'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movie.imdb_score.sort_values(ascending=False).head(15)
# Out:
# Towering Inferno                                     9.5
# The Shawshank Redemption                             9.3
# The Godfather                                        9.2
# Dekalog                                              9.1
# Kickboxer: Vengeance                                 9.1
# The Dark Knight                                      9.0
# Fargo                                                9.0
# The Godfather: Part II                               9.0
# The Good, the Bad and the Ugly                       8.9
# 12 Angry Men                                         8.9
# Schindler's List                                     8.9
# Pulp Fiction                                         8.9
# The Lord of the Rings: The Return of the King        8.9
# Inception                                            8.8
# The Lord of the Rings: The Fellowship of the Ring    8.8
# Name: imdb_score, dtype: float64

# %%
movie.imdb_score

movie.nlargest(100, 'imdb_score').head()
# Out:
#                          color_XXX  num_critic_for_reviews  duration  \
# Towering Inferno             Color                     NaN      65.0
# The Shawshank Redemption     Color                   199.0     142.0
# The Godfather                Color                   208.0     175.0
# Dekalog                      Color                    53.0      55.0
# Kickboxer: Vengeance           NaN                     2.0      90.0
#
#                           director_facebook_likes  actor_3_facebook_likes  \
# Towering Inferno                              0.0                   176.0
# The Shawshank Redemption                      0.0                   461.0
# The Godfather                                 0.0                  3000.0
# Dekalog                                       NaN                     2.0
# Kickboxer: Vengeance                        134.0                   354.0
#
#                              actor_2_name  actor_1_facebook_likes  \
# ...

# %%
movie.nlargest(10, 'imdb_score').head()
# Out:
#                          color_XXX  num_critic_for_reviews  duration  \
# Towering Inferno             Color                     NaN      65.0
# The Shawshank Redemption     Color                   199.0     142.0
# The Godfather                Color                   208.0     175.0
# Dekalog                      Color                    53.0      55.0
# Kickboxer: Vengeance           NaN                     2.0      90.0
#
#                           director_facebook_likes  actor_3_facebook_likes  \
# Towering Inferno                              0.0                   176.0
# The Shawshank Redemption                      0.0                   461.0
# The Godfather                                 0.0                  3000.0
# Dekalog                                       NaN                     2.0
# Kickboxer: Vengeance                        134.0                   354.0
#
#                              actor_2_name  actor_1_facebook_likes  \
# ...

# %%
movie2.sort_values('num_critic_for_reviews',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-128-3924a312285a> in <module>
# ----> 1 movie2.sort_values('num_critic_for_reviews',ascending=False)
#
# NameError: name 'movie2' is not defined

# %%
movie['duration'].dropna().gt(120).mean()

# %%
criteria1 = movie.imdb_score >8

# %%
criteria1

# %%
criteria2 = movie.content_rating == 'PG-13'
criteria2.size

# %%
criteria3 = ((movie.title_year < 2000) |  (movie.title_year > 2009))

# %%
criteria_final = criteria1 & criteria2 & criteria3

# %%
movie[criteria_final]

# %%
movie.values_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-130-4d80e423d1f6> in <module>
# ----> 1 movie.values_counts()
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'values_counts'

# %%
df = pd.read_csv('college.csv')

# %%
df.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# ...

# %%
movie.head()
# Out:
#                                            color_XXX  num_critic_for_reviews  \
# Changed XXX                                    Color                   723.0
# Pirates of the Caribbean: At World's End       Color                   302.0
# Spectre                                        Color                   602.0
# The Dark Knight Rises                          Color                   813.0
# Star Wars: Episode VII - The Force Awakens       NaN                     NaN
#
#                                             duration  director_facebook_likes  \
# Changed XXX                                    178.0                      0.0
# Pirates of the Caribbean: At World's End       169.0                    563.0
# Spectre                                        148.0                      0.0
# The Dark Knight Rises                          164.0                  22000.0
# Star Wars: Episode VII - The Force Awakens       NaN                    131.0
#
# ...

# %% [markdown]
# #Testing
